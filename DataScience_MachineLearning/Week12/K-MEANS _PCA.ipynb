# %% [markdown]
# # K-Means Algorithim and Principal Component Analysis

# %% [markdown]
# #### AI Saturday Lagos Begineers Class (Instructors: `Tejumade Afonja`, `Kenechi Dukor`)
# This exercise is adopted from [Andrew Ng Machine Learning Course](https://www.coursera.org/learn/machine-learning)

# %%
import numpy as np
import pandas as pd
import scipy
from scipy.io import loadmat
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from scipy import linalg

# %% [markdown]
# ## K-Means Alogrithim

# %% [markdown]
# ### Implementing K-Means from Scratch

# %% [markdown]
# ### Loading Data

# %%
X = loadmat('data/ex7data2.mat')['X']

# %%
X.shape
# Out:
# (300, 2)

# %%
# print(X)

# %% [markdown]
# ### Data Visualization

# %%
plt.scatter(X[:,0],X[:,1], marker='+')

# %% [markdown]
# ### Define Function to Implement K-Means

# %%
'''
X : examples
k : no of clusters/centroids
x : centroids
'''
def initialize_centroid(X, k):
    '''
    initialize k centroids
    '''
    i = np.random.choice(X.shape[0], k) # This will return k random index positions on the dataset
    x = X[i] # we set the three random positions to be the centroids
    return x

def plot_centroid(X, x):
    '''
    scatter plot of centroids and examples
    
    '''
    plt.scatter(X[:,0],X[:,1], marker='+')
    plt.scatter(x[:,0],x[:,1], color='r')
    
def get_closer_exam(X,x):
    '''
    Obtain examples that are closer to each centroid
    '''
    c = []
    for i in range(X.shape[0]):
        pos = np.argmin(np.sqrt(np.sum((X[i] - x)**2, axis=1))) # argmin returns the position of the smallest value in the array
        c.append(pos)
    return c
        
def move_cent(X, c):
    '''
    move the centroids position closer to its clustering examples
    '''
    for i in range(3):
        x[i] = (1.0/X[np.array(c) == i].shape[0])*np.sum(X[np.array(c) == i], axis = 0)
    return x

def plt_cluster(X, x, c):
    '''
    plot all clusters
    '''
    for i in range(3):
        plt.scatter(X[np.array(c)==i][:,0], X[np.array(c)==i][:,1], marker='+')
        plt.scatter(x[:,0],x[:,1], color='r')

def distortion(X, x, c):
    '''
    A measure of how well the clusters are formed
    '''
    distances = []
    for i in range(x.shape[0]):
        dis = (1.0/X[np.array(c) == i].shape[0])*np.sum(np.sqrt(np.sum((X[np.array(c) == i]-x[i])**2, axis=1)))
        distances.append(dis)
    
    return distances, (1.0/len(distances))*np.sum(np.array(distances))

# %% [markdown]
# ### Traning / Test

# %% [markdown]
# initialize centroids positions

# %%
x = initialize_centroid(X,3)
x
# Out:
# array([[6.40773863, 2.67554951],
#        [3.56478625, 1.11764714],
#        [2.66046572, 5.19623848]])

# %%
plot_centroid(X, x)

# %% [markdown]
# find examples closer to each centroid

# %%
c = get_closer_exam(X, x)
len(c)
# Out:
# 300

# %% [markdown]
# move each centroid position based on it clusters

# %%
x = move_cent(X, c)

# %%
plt_cluster(X, x,  c)

# %% [markdown]
# obtain the distortion

# %%
dists, dist = distortion(X,x,c)

# %%
dist
# Out:
# 0.7947772960023751

# %% [markdown]
# This steps are usually performed iteratively

# %%
k = 3
x = initialize_centroid(X, k)
distorts = []
for i in range(20):
    c = get_closer_exam(X, x)
    _, dist = distortion(X, x, c)
    distorts.append(dist)
    x = move_cent(X, c)

# %%
distorts
# Out:
# [1.5705678294733856,
#  1.3593316054130447,
#  1.4156781072138822,
#  1.573995181838311,
#  1.4796926721815429,
#  0.9884275649189403,
#  0.8058465682821272,
#  0.7943806559341917,
#  0.7942678193768536,
#  0.7942678193768536,
#  0.7942678193768536,
#  0.7942678193768536,
#  0.7942678193768536,
#  0.7942678193768536,
#  0.7942678193768536,
#  0.7942678193768536,
#  0.7942678193768536,
#  0.7942678193768536,
#  0.7942678193768536,
#  0.7942678193768536]

# %% [markdown]
# plot of distortion at each iteration step

# %%
plt.plot(range(len(distorts)), distorts)

# %%
plt_cluster(X,x,c)

# %% [markdown]
# ### Faster

# %%
data1 = loadmat('data/ex7data2.mat')

# %%
X1 = data1['X']
print('X1:', X1.shape)
# Out:
# X1: (300, 2)

# %%
km1 = KMeans(3)
km1.fit(X1)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
km1.cluster_centers_
# Out:
# array([[1.95399466, 5.02557006],
#        [6.03366736, 3.00052511],
#        [3.04367119, 1.01541041]])

# %%
plt.scatter(X1[:,0], X1[:,1], s=40, c=km1.labels_, cmap=plt.cm.prism) 
plt.title('K-Means Clustering Results with K=3')
plt.scatter(km1.cluster_centers_[:,0], km1.cluster_centers_[:,1], marker='+', s=100, c='k', linewidth=2);

# %% [markdown]
# #### Image compression with K-means

# %%
img = plt.imread('data/bird_small.png')
img_shape = img.shape
img_shape
# Out:
# (128, 128, 3)

# %%
A = img/255

# %%
AA = A.reshape(128*128,3)
AA.shape
# Out:
# (16384, 3)

# %%
km2 = KMeans(100)
km2.fit(AA)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=100, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
km2.cluster_centers_
# Out:
# array([[0.00288164, 0.00271685, 0.00224545],
#        [0.00079385, 0.00079888, 0.00080992],
#        [0.00210019, 0.00182581, 0.00180148],
#        [0.00388676, 0.00386479, 0.00330521],
#        [0.00045083, 0.00048475, 0.00044652],
#        [0.00306524, 0.00250917, 0.00142825],
#        [0.00168779, 0.00120648, 0.00115757],
#        [0.00350945, 0.00319652, 0.00224287],
#        [0.00215633, 0.00149796, 0.00053269],
#        [0.00301632, 0.00221803, 0.000612  ],
#        [0.00138273, 0.00165027, 0.00256349],
#        [0.00211628, 0.00292836, 0.00365458],
#        [0.00339683, 0.00322976, 0.00324188],
#        [0.00358246, 0.00306584, 0.0014615 ],
#        [0.00316901, 0.00241138, 0.00114567],
#        [0.0027047 , 0.00209368, 0.00104874],
#        [0.00134282, 0.00090581, 0.00068909],
#        [0.00319984, 0.002932  , 0.00237167],
#        [0.00379063, 0.00248431, 0.00127456],
#        [0.00022972, 0.00025169, 0.00021312],
#        [0.00170704, 0.00199252, 0.00276062],
#        [0.00257337, 0.00227826, 0.00229259],
#        [0.00123996, 0.00125949, 0.00130033],
#        [0.0031194 , 0.00268126, 0.00272822],
#        [0.00383909, 0.00366774, 0.00276281],
#        [0.00286914, 0.0024929 , 0.00159819],
#        [0.00350099, 0.00329329, 0.00269801],
#        [0.00382434, 0.00263315, 0.00216892],
#        [0.00250835, 0.00161517, 0.00127765],
#        [0.00333123, 0.00293334, 0.0020446 ],
#        [0.00313931, 0.00373361, 0.00373873],
#        [0.00156863, 0.00117255, 0.00055015],
#        [0.00259212, 0.00228212, 0.00159463],
#        [0.00377781, 0.00357366, 0.00247493],
#        [0.00064659, 0.00068282, 0.00068512],
#        [0.00216892, 0.00158474, 0.00153295],
#        [0.00387686, 0.0031784 , 0.00273751],
#        [0.00244405, 0.00170853, 0.00062712],
#        [0.00374559, 0.00221803, 0.00074674],
#        [0.00181727, 0.00173702, 0.0016052 ],
#        [0.00339627, 0.00279934, 0.001625  ],
#        [0.00152392, 0.00176029, 0.00195566],
#        [0.00283914, 0.00255669, 0.00189091],
#        [0.00251847, 0.00330083, 0.00369313],
#        [0.00029716, 0.00032206, 0.00028068],
#        [0.00205397, 0.00177394, 0.00121113],
#        [0.00285974, 0.00244498, 0.0024836 ],
#        [0.00101886, 0.00104915, 0.00116652],
#        [0.00175522, 0.00217967, 0.00317191],
#        [0.00372535, 0.00232385, 0.00165034],
#        [0.00341358, 0.00180625, 0.00091032],
#        [0.00358782, 0.00269937, 0.00100987],
#        [0.00210229, 0.00257398, 0.00339043],
#        [0.00331855, 0.00288639, 0.00297253],
#        [0.00053556, 0.00057447, 0.00054943],
#        [0.00036906, 0.00039804, 0.00035647],
#        [0.00380174, 0.00351457, 0.00330505],
#        [0.00387798, 0.0037734 , 0.00301476],
#        [0.0028381 , 0.00231838, 0.00126988],
#        [0.00238176, 0.00203328, 0.0020296 ],
#        [0.00249689, 0.00282661, 0.00283952],
#        [0.00387836, 0.00380574, 0.00360923],
#        [0.00386272, 0.0028176 , 0.00169668],
#        [0.00166107, 0.0009962 , 0.00082635],
#        [0.00315212, 0.00267174, 0.00170846],
#        [0.00120446, 0.00143791, 0.00221484],
#        [0.00170324, 0.00146051, 0.000894  ],
#        [0.00386587, 0.00308249, 0.00208963],
#        [0.00249369, 0.00185217, 0.00169787],
#        [0.00387851, 0.00334887, 0.00301894],
#        [0.00276161, 0.00189215, 0.00075704],
#        [0.00383329, 0.00293615, 0.00254118],
#        [0.00201146, 0.00217321, 0.00215135],
#        [0.00351089, 0.00208544, 0.00126105],
#        [0.00246004, 0.0024945 , 0.00200572],
#        [0.00185592, 0.00146351, 0.00132274],
#        [0.0032009 , 0.00244332, 0.00211658],
#        [0.00095999, 0.00094343, 0.00093339],
#        [0.00139403, 0.00147874, 0.00157287],
#        [0.00344728, 0.00200238, 0.00034043],
#        [0.00331995, 0.00263633, 0.00143146],
#        [0.00204912, 0.00130944, 0.00101931],
#        [0.00188962, 0.00125065, 0.00047614],
#        [0.00136106, 0.00112617, 0.00097493],
#        [0.00296667, 0.00217076, 0.00101632],
#        [0.00295463, 0.00211169, 0.00164768],
#        [0.00245893, 0.00203705, 0.00127865],
#        [0.00209216, 0.00167911, 0.00082052],
#        [0.00374815, 0.00348129, 0.00217265],
#        [0.00224145, 0.00247549, 0.00260957],
#        [0.00108583, 0.00077463, 0.00057834],
#        [0.00341016, 0.00288694, 0.00183558],
#        [0.00312713, 0.00277829, 0.00198604],
#        [0.00280095, 0.00314944, 0.00314509],
#        [0.00276976, 0.00215037, 0.00207118],
#        [0.00103369, 0.00112687, 0.00171759],
#        [0.00246472, 0.00187676, 0.00085084],
#        [0.00078884, 0.00065185, 0.00045697],
#        [0.00219539, 0.00209693, 0.00163497],
#        [0.00363607, 0.00323851, 0.00187955]], dtype=float32)

# %%
km2.labels_
# Out:
# array([40, 91, 40, ..., 90, 97, 97], dtype=int32)

# %%
B = km2.cluster_centers_[km2.labels_].reshape(img_shape[0], img_shape[1], 3)

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(13,9))
ax1.imshow(img)
ax1.set_title('Original')
ax2.imshow(B*255)
ax2.set_title('Compressed, with 16 colors')

for ax in fig.axes:
    ax.axis('off')

# %% [markdown]
# ### PCA on example data set

# %% [markdown]
# Using scipy instead of scikit-learn

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn; 
from sklearn import neighbors, datasets

import pylab as pl

seaborn.set()

iris = datasets.load_iris()

X, y = iris.data, iris.target
from sklearn.decomposition import PCA

# %% [markdown]
# Attribute Information:
#
# 1. sepal length in cm
# 2. sepal width in cm
# 3. petal length in cm
# 4. petal width in cm
# 5. class:
# -- Iris Setosa
# -- Iris Versicolour
# -- Iris Virginica

# %%
X.shape
# Out:
# (150, 4)

# %%
pca = PCA(n_components=2)
pca.fit(X)
X_reduced = pca.transform(X)
print("Reduced dataset shape:", X_reduced.shape)

pl.scatter(X_reduced[:, 0], X_reduced[:, 1], c=y,
           cmap='Paired')
# Out:
# Reduced dataset shape: (150, 2)

# %%
# pca.components_

# %%
# print("Meaning of the 2 components:")
# for component in pca.components_:
#     print(" + ".join("%.3f x %s" % (value, name)
#                      for value, name in zip(component,
#                                             iris.feature_names)))
